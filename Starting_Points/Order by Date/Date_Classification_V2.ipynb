# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# %matplotlib inline
import matplotlib.pyplot as plt
from random import seed # for setting seed
import tensorflow
from IPython import sys_info
import os
import gc # garbage collection
import random
import os
import shutil
import tensorflow as tf
from tensorflow.keras import layers, models

# %%
from tensorflow.python.client import device_lib
# print out the CPUs and GPUs
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 16602765337550159918
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 14626652160
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 13436154390335948252
# physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
# xla_global_id: 416903419
# ]

# %%
from PIL import Image
Image.MAX_IMAGE_PIXELS = None

# %%
from tensorflow.keras.applications import ResNet50, VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, GlobalAveragePooling2D, Input

from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import Sequence
from tensorflow.keras import layers, models, optimizers

# %%
folder = '/content/drive/My Drive/PROJECTE DEEP LEARNING/TOP5_ARTISTS_WITH_100_PICTURES'

# List the files in the folder
all_pictures = os.listdir(folder)

file_path = "/content/drive/My Drive/PROJECTE DEEP LEARNING/TOP5_ARTISTS_WITH_100_PICTURES.csv"
df = pd.read_csv(file_path)

# All date to int
df['date'] = df['date'].str.replace('c.', '').astype('int', errors='ignore')

print(df.head())
# Out:
#          artist  date                  genre  pixelsx  pixelsy  size_bytes  \
# 0  Paul Gauguin  1903         genre painting   1916.0   1688.0    363138.0
# 1  Paul Gauguin  1893               portrait   2048.0   1348.0    293452.0
# 2  Paul Gauguin  1892  mythological painting   1800.0   1082.0   1638911.0
# 3  Paul Gauguin  1903         genre painting   1600.0   1067.0    307130.0
# 4  Paul Gauguin  1892               portrait   1096.0   1476.0    467406.0
#
#     source               style                  title    artist_group  \
# 0  wikiart  Post-Impressionism         The Invocation  train_and_test
# 1  wikiart         Cloisonnism                  Alone  train_and_test
# 2  wikiart         Cloisonnism          The Royal End  train_and_test
# 3  wikiart  Post-Impressionism  Women and white horse  train_and_test
# 4  wikiart  Post-Impressionism            Two sisters  train_and_test
#
#    in_train new_filename
# 0     False    35323.jpg
# 1     False    73683.jpg
# 2      True   101871.jpg
# 3      True    76989.jpg
# 4     False    89439.jpg

# %% [markdown]
# # Create the TEST and TRAIN sets

# %%
# Function to read filenames from a folder and return a list of filenames
def get_filenames_from_folder(folder_path):
    filenames = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
    return filenames

# Check if the TRAIN and TEST folders exist
if os.path.exists(os.path.join(folder, 'TRAIN')) and os.path.exists(os.path.join(folder, 'TEST')):
    print("TRAIN and TEST folders exist. Reading image filenames...")

    # Get filenames from the TRAIN and TEST folders
    train_filenames = get_filenames_from_folder(os.path.join(folder, 'TRAIN'))
    test_filenames = get_filenames_from_folder(os.path.join(folder, 'TEST'))

    # Filter the df DataFrame to get the train and test DataFrames
    train_dataframe = df[df['new_filename'].isin(train_filenames)][['artist','date', 'new_filename']]
    test_dataframe = df[df['new_filename'].isin(test_filenames)][['artist','date', 'new_filename']]

    print("Train DataFrame:", train_dataframe.shape)
    print("Test DataFrame:", test_dataframe.shape)
else:
    print("TRAIN and TEST folders do not exist. Please create the folders and try again.")
# Out:
# TRAIN and TEST folders exist. Reading image filenames...
# Train DataFrame: (400, 3)
# Test DataFrame: (100, 3)

# %%
train_dataframe.head()
# Out:
#          artist  date new_filename
# 0  Paul Gauguin  1903    35323.jpg
# 2  Paul Gauguin  1892   101871.jpg
# 3  Paul Gauguin  1903    76989.jpg
# 4  Paul Gauguin  1892    89439.jpg
# 5  Paul Gauguin  1885    64788.jpg

# %%
import numpy as np
from PIL import Image
import os

def get_meanstd(df, image_dir):
    means = []
    stds = []
    for idx, row in df.iterrows():
        img_path = os.path.join(image_dir, row['new_filename'])
        img = np.array(Image.open(img_path)) / 255.0
        means.append(np.mean(img, axis=(0, 1)))
        stds.append(np.std(img, axis=(0, 1)))

    meanR = np.mean([m[0] for m in means])
    meanG = np.mean([m[1] for m in means])
    meanB = np.mean([m[2] for m in means])

    stdR = np.mean([s[0] for s in stds])
    stdG = np.mean([s[1] for s in stds])
    stdB = np.mean([s[2] for s in stds])

    return [meanR, meanG, meanB], [stdR, stdG, stdB]


means, stds = get_meanstd(train_dataframe, folder+"/TRAIN")
print(f'Mean Values: {means}')
print(f'STD Values: {stds}')
# Out:
# Mean Values: [0.4902860351171657, 0.4327027123349515, 0.3679902021355657]
# STD Values: [0.22134062718873712, 0.20430693703606892, 0.18851782142531143]

# %%
import itertools

def load_image(image_path,  means=None, stds=None):
    image = Image.open(image_path)
    image = np.array(image) / 255.0  # Normalize

    # Normalize using means and stds
    if means is not None and stds is not None:
        image = (image - means) / stds

    return image

def create_pairs_by_artist(df, image_dir, means, stds, mode):
    pairs = []
    labels = []
    artists = df['artist'].unique()

    for artist in artists:
        if mode == "TRAIN":
          artist_df = df[df['artist'] == artist].head(20)
        else:
          artist_df = df[df['artist'] == artist].head(9)
        artist_images = [os.path.join(image_dir, filename) for filename in artist_df['new_filename']]
        artist_pairs = list(itertools.combinations(artist_images, 2))

        for pair in artist_pairs:
            date_img1 = artist_df[artist_df['new_filename'] == pair[0].split("/")[-1]]['date'].tolist()[0]
            date_img2 = artist_df[artist_df['new_filename'] == pair[1].split("/")[-1]]['date'].tolist()[0]
            img1 = load_image(pair[0], means=means, stds=stds) # Load normalizing
            img2 = load_image(pair[1], means=means, stds=stds) # Load normalizing

            pairs.append([img1, img2])
            label = 1 if date_img1 > date_img2 else 0
            labels.append(label)

    return np.array(pairs), np.array(labels)
# Create training and test pairs
train_pairs, train_labels = create_pairs_by_artist(train_dataframe, folder+"/TRAIN", means, stds, mode = "TRAIN")
test_pairs, test_labels = create_pairs_by_artist(test_dataframe, folder+"/TEST", means, stds, mode = "TEST")

# %%
print("Number of pairs in TRAIN:", len(train_pairs))
print("Number of pairs in TEST:", len(test_pairs))
# Out:
# Number of pairs in TRAIN: 950
# Number of pairs in TEST: 180

# %%
from torchvision import transforms

train_dataframe = train_dataframe.drop(columns=['artist'])
test_dataframe = test_dataframe.drop(columns=['artist'])
# Data Transformation

# Transformations for training set
train_transformer = transforms.Compose([transforms.RandomHorizontalFlip(p=0.5),
                                        transforms.RandomVerticalFlip(p=0.5),
                                        transforms.ToTensor(),
                                        transforms.Normalize([means[0], means[1], means[2]],
                                                             [stds[0], stds[1], stds[2]])])

# Standard transformations for test set
test0_transformer = transforms.Compose([transforms.ToTensor(),
                                        transforms.Normalize([means[0], means[1], means[2]],
                                                             [stds[0], stds[1], stds[2]])])

# Update the transform functions for train_ds & test_all
train_dataframe.transform = train_transformer
test_dataframe.transform = test0_transformer

# %%
# Plotting the training and validation curves for loss and accuracy
def plot_out(loss_hist, metric_hist, epochs=None):
    # Create the figure and axes
    fig, axs = plt.subplots(1, 2, figsize=(12, 6))

    # Loss history plot
    axs[0].plot(range(1, epochs+1), loss_hist["train"], label="Train loss")
    axs[0].plot(range(1, epochs+1), loss_hist["val"], label="Validation loss")
    axs[0].set_title('Loss History')
    axs[0].set_xlabel('Epoch')
    axs[0].set_ylabel('Loss')
    axs[0].legend()

    # Metric history plot
    axs[1].plot(range(1, epochs+1), metric_hist["train"], label="Train accuracy")
    axs[1].plot(range(1, epochs+1), metric_hist["val"], label="Validation accuracy")
    axs[1].set_title('Accuracy History')
    axs[1].set_xlabel('Epoch')
    axs[1].set_ylabel('Accuracy')
    axs[1].legend()

    # Adjust spacing between subplots
    plt.tight_layout()

    # Show the plot
    plt.show()

# %% [markdown]
# # Vgg16

# %%
input_shape = (224, 224, 3)
learning_rate = 1e-4

def create_model(input_shape):
    base_model = tf.keras.applications.VGG16(include_top=False, input_shape=input_shape, weights='imagenet')
    base_model.trainable = False

    input_1 = layers.Input(shape=input_shape)
    input_2 = layers.Input(shape=input_shape)

    x1 = base_model(input_1)
    x2 = base_model(input_2)

    x1 = layers.Flatten()(x1)
    x2 = layers.Flatten()(x2)

    concatenated = layers.Concatenate()([x1, x2])

    dense = layers.Dense(512, activation='relu')(concatenated)
    dense = layers.Dense(256, activation='relu')(dense)
    output = layers.Dense(1, activation='sigmoid')(dense)

    model = models.Model(inputs=[input_1, input_2], outputs=output)

    # Create the optimizer with your desired learning rate
    optimizer = optimizers.Adam(learning_rate=learning_rate)

    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    return model

model = create_model(input_shape)
model.summary()

history = model.fit([train_pairs[:, 0], train_pairs[:, 1]], train_labels, epochs=50, batch_size=32, validation_split=0.2)

test_loss, test_accuracy = model.evaluate([test_pairs[:, 0], test_pairs[:, 1]], test_labels)
print(f'Test accuracy: {test_accuracy:.2f}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  input_3 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  vgg16 (Functional)          (None, 7, 7, 512)            1471468   ['input_2[0][0]',
#                                                           8          'input_3[0][0]']
#
#  flatten (Flatten)           (None, 25088)                0         ['vgg16[0][0]']
#
#  flatten_1 (Flatten)         (None, 25088)                0         ['vgg16[1][0]']
#
#  concatenate (Concatenate)   (None, 50176)                0         ['flatten[0][0]',
#                                                                      'flatten_1[0][0]']
#
#  dense (Dense)               (None, 512)                  2569062   ['concatenate[0][0]']
#                                                           4
#
#  dense_1 (Dense)             (None, 256)                  131328    ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 1)                    257       ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 40536897 (154.64 MB)
# Trainable params: 25822209 (98.50 MB)
# Non-trainable params: 14714688 (56.13 MB)
# __________________________________________________________________________________________________
# Epoch 1/50
# 24/24 [==============================] - 54s 2s/step - loss: 0.6300 - accuracy: 0.6816 - val_loss: 0.6035 - val_accuracy: 0.6526
# Epoch 2/50
# 24/24 [==============================] - 8s 312ms/step - loss: 0.2046 - accuracy: 0.9368 - val_loss: 0.5814 - val_accuracy: 0.6737
# Epoch 3/50
# 24/24 [==============================] - 9s 360ms/step - loss: 0.1644 - accuracy: 0.9316 - val_loss: 0.5872 - val_accuracy: 0.6895
# Epoch 4/50
# 24/24 [==============================] - 8s 316ms/step - loss: 0.0846 - accuracy: 0.9763 - val_loss: 0.6303 - val_accuracy: 0.6789
# Epoch 5/50
# 24/24 [==============================] - 9s 364ms/step - loss: 0.0725 - accuracy: 0.9697 - val_loss: 0.7002 - val_accuracy: 0.6684
# Epoch 6/50
# 24/24 [==============================] - 9s 365ms/step - loss: 0.0580 - accuracy: 0.9842 - val_loss: 0.6813 - val_accuracy: 0.6737
# Epoch 7/50
# 24/24 [==============================] - 9s 370ms/step - loss: 0.0350 - accuracy: 0.9895 - val_loss: 0.7018 - val_accuracy: 0.6895
# Epoch 8/50
# 24/24 [==============================] - 9s 371ms/step - loss: 0.0194 - accuracy: 0.9961 - val_loss: 0.7414 - val_accuracy: 0.6789
# Epoch 9/50
# 24/24 [==============================] - 9s 374ms/step - loss: 0.0140 - accuracy: 0.9987 - val_loss: 0.7932 - val_accuracy: 0.6684
# Epoch 10/50
# 24/24 [==============================] - 9s 380ms/step - loss: 0.0080 - accuracy: 0.9987 - val_loss: 0.8116 - val_accuracy: 0.6737
# Epoch 11/50
# 24/24 [==============================] - 9s 379ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.8175 - val_accuracy: 0.6789
# Epoch 12/50
# 24/24 [==============================] - 9s 373ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.8268 - val_accuracy: 0.6684
# Epoch 13/50
# 24/24 [==============================] - 9s 375ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.8233 - val_accuracy: 0.6737
# Epoch 14/50
# 24/24 [==============================] - 8s 328ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.8580 - val_accuracy: 0.6737
# Epoch 15/50
# 24/24 [==============================] - 9s 372ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.8575 - val_accuracy: 0.6737
# Epoch 16/50
# 24/24 [==============================] - 8s 330ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.8771 - val_accuracy: 0.6737
# Epoch 17/50
# 24/24 [==============================] - 9s 375ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.8952 - val_accuracy: 0.6737
# Epoch 18/50
# 24/24 [==============================] - 8s 329ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.8921 - val_accuracy: 0.6737
# Epoch 19/50
# 24/24 [==============================] - 9s 378ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.8995 - val_accuracy: 0.6737
# Epoch 20/50
# 24/24 [==============================] - 9s 375ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.
# Epoch 40/50
# 24/24 [==============================] - 9s 377ms/step - loss: 2.0683e-04 - accuracy: 1.0000 - val_loss: 1.0658 - val_accuracy: 0.6737
# Epoch 41/50
# 24/24 [==============================] - 9s 374ms/step - loss: 1.9456e-04 - accuracy: 1.0000 - val_loss: 1.0741 - val_accuracy: 0.6737
# Epoch 42/50
# 24/24 [==============================] - 9s 374ms/step - loss: 1.8143e-04 - accuracy: 1.0000 - val_loss: 1.0782 - val_accuracy: 0.6737
# Epoch 43/50
# 24/24 [==============================] - 8s 333ms/step - loss: 1.7127e-04 - accuracy: 1.0000 - val_loss: 1.0933 - val_accuracy: 0.6684
# Epoch 44/50
# 24/24 [==============================] - 9s 374ms/step - loss: 1.6018e-04 - accuracy: 1.0000 - val_loss: 1.0901 - val_accuracy: 0.6737
# Epoch 45/50
# 24/24 [==============================] - 8s 331ms/step - loss: 1.4951e-04 - accuracy: 1.0000 - val_loss: 1.1021 - val_accuracy: 0.6684
# Epoch 46/50
# 24/24 [==============================] - 8s 334ms/step - loss: 1.3960e-04 - accuracy: 1.0000 - val_loss: 1.1108 - val_accuracy: 0.6684
# Epoch 47/50
# 24/24 [==============================] - 9s 374ms/step - loss: 1.3117e-04 - accuracy: 1.0000 - val_loss: 1.1105 - val_accuracy: 0.6684
# Epoch 48/50
# 24/24 [==============================] - 9s 376ms/step - loss: 1.2358e-04 - accuracy: 1.0000 - val_loss: 1.1208 - val_accuracy: 0.6684
# Epoch 49/50
# 24/24 [==============================] - 9s 376ms/step - loss: 1.1490e-04 - accuracy: 1.0000 - val_loss: 1.1339 - val_accuracy: 0.6684
# Epoch 50/50
# 24/24 [==============================] - 8s 328ms/step - loss: 1.0838e-04 - accuracy: 1.0000 - val_loss: 1.1369 - val_accuracy: 0.6684
# 6/6 [==============================] - 6s 1s/step - loss: 1.3788 - accuracy: 0.5667
# Test accuracy: 0.57

# %%
# Prepare the data for the plot_out function
loss_hist = {
    "train": history.history['loss'],
    "val": history.history['val_loss']
}

metric_hist = {
    "train": history.history['accuracy'],
    "val": history.history['val_accuracy']
}

# Call the plot_out function
plot_out(loss_hist, metric_hist, epochs=len(history.history['loss']))

# %%
# Free up memory
del model
del history

# %% [markdown]
# # Avoid Overfitting Vgg16

# %% [markdown]
# ## Unfreezing the last 2 layers and applying L2 regularization and dropout.

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, regularizers

input_shape = (224, 224, 3)
learning_rate = 1e-4

def create_model(input_shape):
    base_model = tf.keras.applications.VGG16(include_top=False, input_shape=input_shape, weights='imagenet')

    for layer in base_model.layers:
        layer.trainable = False

    for layer in base_model.layers[-2:]:
        layer.trainable = True

    input_1 = layers.Input(shape=input_shape)
    input_2 = layers.Input(shape=input_shape)

    x1 = base_model(input_1)
    x2 = base_model(input_2)

    x1 = layers.Flatten()(x1)
    x2 = layers.Flatten()(x2)

    concatenated = layers.Concatenate()([x1, x2])

    # Agregar regularización L2 y dropout
    dense = layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.01))(concatenated)
    dense = layers.Dropout(0.5)(dense)
    dense = layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01))(dense)
    dense = layers.Dropout(0.5)(dense)
    output = layers.Dense(1, activation='sigmoid')(dense)

    model = models.Model(inputs=[input_1, input_2], outputs=output)

    optimizer = optimizers.Adam(learning_rate=learning_rate)

    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    return model

model = create_model(input_shape)
model.summary()

history = model.fit([train_pairs[:, 0], train_pairs[:, 1]], train_labels, epochs=50, batch_size=32, validation_split=0.2)

test_loss, test_accuracy = model.evaluate([test_pairs[:, 0], test_pairs[:, 1]], test_labels)
print(f'Test accuracy: {test_accuracy:.2f}')
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  input_6 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  vgg16 (Functional)          (None, 7, 7, 512)            1471468   ['input_5[0][0]',
#                                                           8          'input_6[0][0]']
#
#  flatten_2 (Flatten)         (None, 25088)                0         ['vgg16[0][0]']
#
#  flatten_3 (Flatten)         (None, 25088)                0         ['vgg16[1][0]']
#
#  concatenate_1 (Concatenate  (None, 50176)                0         ['flatten_2[0][0]',
#  )                                                                   'flatten_3[0][0]']
#
#  dense_3 (Dense)             (None, 512)                  2569062   ['concatenate_1[0][0]']
#                                                           4
#
#  dropout (Dropout)           (None, 512)                  0         ['dense_3[0][0]']
#
#  dense_4 (Dense)             (None, 256)                  131328    ['dropout[0][0]']
#
#  dropout_1 (Dropout)         (None, 256)                  0         ['dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 1)                    257       ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 40536897 (154.64 MB)
# Trainable params: 28182017 (107.51 MB)
# Non-trainable params: 12354880 (47.13 MB)
# __________________________________________________________________________________________________
# Epoch 1/50
# 24/24 [==============================] -
# 24/24 [==============================] - 9s 391ms/step - loss: 0.8309 - accuracy: 0.9947 - val_loss: 1.9912 - val_accuracy: 0.6947
# Epoch 43/50
# 24/24 [==============================] - 9s 387ms/step - loss: 0.7922 - accuracy: 0.9961 - val_loss: 1.9094 - val_accuracy: 0.7211
# Epoch 44/50
# 24/24 [==============================] - 9s 387ms/step - loss: 0.7640 - accuracy: 0.9947 - val_loss: 2.0177 - val_accuracy: 0.7000
# Epoch 45/50
# 24/24 [==============================] - 9s 389ms/step - loss: 0.7403 - accuracy: 0.9947 - val_loss: 1.7870 - val_accuracy: 0.7105
# Epoch 46/50
# 24/24 [==============================] - 9s 390ms/step - loss: 0.7130 - accuracy: 0.9908 - val_loss: 1.8025 - val_accuracy: 0.7316
# Epoch 47/50
# 24/24 [==============================] - 9s 388ms/step - loss: 0.6935 - accuracy: 0.9921 - val_loss: 1.7067 - val_accuracy: 0.7368
# Epoch 48/50
# 24/24 [==============================] - 9s 388ms/step - loss: 0.6755 - accuracy: 0.9895 - val_loss: 1.6977 - val_accuracy: 0.7000
# Epoch 49/50
# 24/24 [==============================] - 8s 345ms/step - loss: 0.6422 - accuracy: 0.9961 - val_loss: 1.9109 - val_accuracy: 0.7053
# Epoch 50/50
# 24/24 [==============================] - 9s 386ms/step - loss: 0.6175 - accuracy: 0.9947 - val_loss: 1.7672 - val_accuracy: 0.7158
# 6/6 [==============================] - 2s 238ms/step - loss: 2.5418 - accuracy: 0.6111
# Test accuracy: 0.61

# %%
# Prepare the data for the plot_out function
loss_hist = {
    "train": history.history['loss'],
    "val": history.history['val_loss']
}

metric_hist = {
    "train": history.history['accuracy'],
    "val": history.history['val_accuracy']
}

# Call the plot_out function
plot_out(loss_hist, metric_hist, epochs=len(history.history['loss']))

# %% [markdown]
# ## Unfreezing the last layer and applying L2 regularization and dropout.

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, regularizers, callbacks

input_shape = (224, 224, 3)
learning_rate = 1e-4

def create_model(input_shape):
    base_model = tf.keras.applications.VGG16(include_top=False, input_shape=input_shape, weights='imagenet')

    for layer in base_model.layers:
        layer.trainable = False

    for layer in base_model.layers[-1:]:
        layer.trainable = True

    input_1 = layers.Input(shape=input_shape)
    input_2 = layers.Input(shape=input_shape)

    x1 = base_model(input_1)
    x2 = base_model(input_2)

    x1 = layers.Flatten()(x1)
    x2 = layers.Flatten()(x2)

    concatenated = layers.Concatenate()([x1, x2])

    # Añadir Batch Normalization y Dropout
    dense = layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.01))(concatenated)
    dense = layers.BatchNormalization()(dense)
    dense = layers.Dropout(0.5)(dense)
    dense = layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01))(dense)
    dense = layers.BatchNormalization()(dense)
    dense = layers.Dropout(0.5)(dense)
    output = layers.Dense(1, activation='sigmoid')(dense)

    model = models.Model(inputs=[input_1, input_2], outputs=output)

    optimizer = optimizers.Adam(learning_rate=learning_rate)

    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    return model

model = create_model(input_shape)
model.summary()

# Early stopping and ReduceLROnPlateau callbacks
early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6)

history = model.fit(
    [train_pairs[:, 0], train_pairs[:, 1]], train_labels,
    epochs=50,
    batch_size=32,
    validation_split=0.2,
    callbacks=[early_stopping, reduce_lr]
)

test_loss, test_accuracy = model.evaluate([test_pairs[:, 0], test_pairs[:, 1]], test_labels)
print(f'Test accuracy: {test_accuracy:.2f}')
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_8 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  input_9 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  vgg16 (Functional)          (None, 7, 7, 512)            1471468   ['input_8[0][0]',
#                                                           8          'input_9[0][0]']
#
#  flatten_4 (Flatten)         (None, 25088)                0         ['vgg16[0][0]']
#
#  flatten_5 (Flatten)         (None, 25088)                0         ['vgg16[1][0]']
#
#  concatenate_2 (Concatenate  (None, 50176)                0         ['flatten_4[0][0]',
#  )                                                                   'flatten_5[0][0]']
#
#  dense_6 (Dense)             (None, 512)                  2569062   ['concatenate_2[0][0]']
#                                                           4
#
#  batch_normalization (Batch  (None, 512)                  2048      ['dense_6[0][0]']
#  Normalization)
#
#  dropout_2 (Dropout)         (None, 512)                  0         ['batch_normalization[0][0]']
#
#  dense_7 (Dense)             (None, 256)                  131328    ['dropout_2[0][0]']
#
#  batch_normalization_1 (Bat  (None, 256)                  1024      ['dense_7[0][0]']
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 256)                  0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  dense_8 (Dense)             (None, 1)                    257       ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 40539969 (154.65 MB)
# Trainable params: 25823745 (98.51 MB)
# Non-trainable params: 14716224 (56.14 MB)
# __________________________________________________________________________________________________
# Epoch 1/50
# 24/24 [==============================] - 13s 445ms/step - loss: 13.5130 - accuracy: 0.6829 - val_loss: 12.8435 - val_accuracy: 0.6158 - lr: 1.0000e-04
# Epoch 2/50
# 24/24 [==============================] - 9s 389ms/step - loss: 12.0961 - accuracy: 0.8132 - val_loss: 11.9120 - val_accuracy: 0.6474 - lr: 1.0000e-04
# Epoch 3/50
# 24/24 [==============================] - 9s 396ms/step - loss: 11.1864 - accuracy: 0.8829 - val_loss: 11.2365 - val_accuracy: 0.6579 - lr: 1.0000e-04
# Epoch 4/50
# 24/24 [==============================] - 9s 394ms/step - loss: 10.5750 - accuracy: 0.8684 - val_loss: 10.6483 - val_accuracy: 0.6632 - lr: 1.0000e-04
# Epoch
- val_accuracy: 0.6000 - lr: 1.0000e-04
# Epoch 45/50
# 24/24 [==============================] - 9s 376ms/step - loss: 2.0663 - accuracy: 0.9632 - val_loss: 2.9989 - val_accuracy: 0.6421 - lr: 1.0000e-04
# Epoch 46/50
# 24/24 [==============================] - 9s 388ms/step - loss: 2.0406 - accuracy: 0.9684 - val_loss: 2.9081 - val_accuracy: 0.6579 - lr: 2.0000e-05
# Epoch 47/50
# 24/24 [==============================] - 9s 386ms/step - loss: 1.9831 - accuracy: 0.9724 - val_loss: 2.7957 - val_accuracy: 0.6684 - lr: 2.0000e-05
# Epoch 48/50
# 24/24 [==============================] - 9s 385ms/step - loss: 1.9784 - accuracy: 0.9737 - val_loss: 2.7887 - val_accuracy: 0.6737 - lr: 2.0000e-05
# Epoch 49/50
# 24/24 [==============================] - 9s 388ms/step - loss: 1.9459 - accuracy: 0.9829 - val_loss: 2.7781 - val_accuracy: 0.6737 - lr: 2.0000e-05
# Epoch 50/50
# 24/24 [==============================] - 8s 342ms/step - loss: 1.9340 - accuracy: 0.9803 - val_loss: 2.7465 - val_accuracy: 0.6789 - lr: 2.0000e-05
# 6/6 [==============================] - 2s 245ms/step - loss: 2.9112 - accuracy: 0.5556
# Test accuracy: 0.56

# %%
# Prepare the data for the plot_out function
loss_hist = {
    "train": history.history['loss'],
    "val": history.history['val_loss']
}

metric_hist = {
    "train": history.history['accuracy'],
    "val": history.history['val_accuracy']
}

# Call the plot_out function
plot_out(loss_hist, metric_hist, epochs=len(history.history['loss']))

# %% [markdown]
# ## Unfreezing the last 2 layers and applying L2 regularization, earlystopping and dropout.

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, regularizers, callbacks

input_shape = (224, 224, 3)
learning_rate = 1e-4

def create_model(input_shape):
    base_model = tf.keras.applications.VGG16(include_top=False, input_shape=input_shape, weights='imagenet')

    for layer in base_model.layers:
        layer.trainable = False

    for layer in base_model.layers[-2:]:
        layer.trainable = True

    input_1 = layers.Input(shape=input_shape)
    input_2 = layers.Input(shape=input_shape)

    x1 = base_model(input_1)
    x2 = base_model(input_2)

    x1 = layers.Flatten()(x1)
    x2 = layers.Flatten()(x2)

    concatenated = layers.Concatenate()([x1, x2])

    dense = layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.01), activity_regularizer=regularizers.l2(0.01))(concatenated)
    dense = layers.Dropout(0.6)(dense)  # Increased dropout rate
    dense = layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01), activity_regularizer=regularizers.l2(0.01))(dense)
    dense = layers.Dropout(0.6)(dense)  # Increased dropout rate
    output = layers.Dense(1, activation='sigmoid')(dense)

    model = models.Model(inputs=[input_1, input_2], outputs=output)

    optimizer = optimizers.Adam(learning_rate=learning_rate)

    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    return model

model = create_model(input_shape)
model.summary()

early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit([train_pairs[:, 0], train_pairs[:, 1]], train_labels,
                    epochs=50, batch_size=32, validation_split=0.2,
                    callbacks=[early_stopping])

test_loss, test_accuracy = model.evaluate([test_pairs[:, 0], test_pairs[:, 1]], test_labels)
print(f'Test accuracy: {test_accuracy:.2f}')
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  input_3 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  vgg16 (Functional)          (None, 7, 7, 512)            1471468   ['input_2[0][0]',
#                                                           8          'input_3[0][0]']
#
#  flatten (Flatten)           (None, 25088)                0         ['vgg16[0][0]']
#
#  flatten_1 (Flatten)         (None, 25088)                0         ['vgg16[1][0]']
#
#  concatenate (Concatenate)   (None, 50176)                0         ['flatten[0][0]',
#                                                                      'flatten_1[0][0]']
#
#  dense (Dense)               (None, 512)                  2569062   ['concatenate[0][0]']
#                                                           4
#
#  dropout (Dropout)           (None, 512)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 256)                  131328    ['dropout[0][0]']
#
#  dropout_1 (Dropout)         (None, 256)                  0         ['dense_1[0][0]']
#
#  dense_2 (Dense)             (None, 1)                    257       ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 40536897 (154.64 MB)
# Trainable params: 28182017 (107.51 MB)
# Non-trainable params: 12354880 (47.13 MB)
# __________________________________________________________________________________________________
# Epoch 1/50
# 24/24 [==============================] - 59s 2s/step - loss: 13.1656 - accuracy: 0.5947 - val_loss: 11.4050 - val_accuracy: 0.4053
# Epoch 2/50
# 24/24 [==============================] - 9s 396ms/step - loss: 10.3058 - accuracy: 0.6145 - val_loss: 9.2317 - val_accuracy: 0.3474
# Epoch 3/50
# 24/24 [==============================] - 9s 397ms/step - loss: 8.4735 - accuracy: 0.6447 - val_loss: 7.7434 - val_accuracy: 0.3579
# Epoch 4/50
# 24/24 [==============================] - 9s 398ms/step - loss: 7.2153 - accuracy: 0.6197 - val_loss: 6.7010 - val_accuracy: 0.3684
# Epoch 5/50
# 24/24 [==============================] - 9s 358ms/step - loss: 6.3092 - accuracy: 0.6184 - val_loss: 5.9258 - val_accuracy: 0.6158
# Epoch 6/50
# 24/24 [==============================] - 10s 405ms/step - loss: 5.6227 - accuracy: 0.6421 - val_loss: 5.3256 - val_accuracy: 0.3842
# Epoch 7/50
# 24/24 [==============================] - 10s 403ms/step - loss: 5.0631 - accuracy: 0.6934 - val_loss: 4.8298 - val_accuracy: 0.3842
# Epoch 8/50
# 24/24 [==============================] - 9s 359ms/step - loss: 4.5975 - accuracy: 0.7237 - val_loss: 4.4040 - val_accuracy: 0.5053
# Epoch 9/50
# 24/24 [==============================] - 10s 402ms/step - loss: 4.1866 - accuracy: 0.7447 - val_loss: 4.0279 - val_accuracy: 0.5895
# Epoch 10/50
# 24/24 [==============================] - 9s 400ms/step - loss: 3.8257 - accuracy: 0.7658 - val_loss: 3.7244 - val_accuracy: 0.4737
# Epoch 11/50
# %%
# Prepare the data for the plot_out function
loss_hist = {
    "train": history.history['loss'],
    "val": history.history['val_loss']
}

metric_hist = {
    "train": history.history['accuracy'],
    "val": history.history['val_accuracy']
}

# Call the plot_out function
plot_out(loss_hist, metric_hist, epochs=len(history.history['loss']))

# %% [markdown]
# ## Unfreezing more layers (last 4)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, regularizers, callbacks

input_shape = (224, 224, 3)
learning_rate = 1e-4

def create_model(input_shape):
    base_model = tf.keras.applications.VGG16(include_top=False, input_shape=input_shape, weights='imagenet')

    for layer in base_model.layers:
        layer.trainable = False

    for layer in base_model.layers[-4:]:
        layer.trainable = True

    input_1 = layers.Input(shape=input_shape)
    input_2 = layers.Input(shape=input_shape)

    x1 = base_model(input_1)
    x2 = base_model(input_2)

    x1 = layers.Flatten()(x1)
    x2 = layers.Flatten()(x2)

    concatenated = layers.Concatenate()([x1, x2])

    dense = layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.01), activity_regularizer=regularizers.l2(0.01))(concatenated)
    dense = layers.Dropout(0.6)(dense)  # Increased dropout rate
    dense = layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01), activity_regularizer=regularizers.l2(0.01))(dense)
    dense = layers.Dropout(0.6)(dense)  # Increased dropout rate
    output = layers.Dense(1, activation='sigmoid')(dense)

    model = models.Model(inputs=[input_1, input_2], outputs=output)

    optimizer = optimizers.Adam(learning_rate=learning_rate)

    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    return model

model = create_model(input_shape)
model.summary()

early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit([train_pairs[:, 0], train_pairs[:, 1]], train_labels,
                    epochs=50, batch_size=32, validation_split=0.2,
                    callbacks=[early_stopping])

test_loss, test_accuracy = model.evaluate([test_pairs[:, 0], test_pairs[:, 1]], test_labels)
print(f'Test accuracy: {test_accuracy:.2f}')
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_11 (InputLayer)       [(None, 224, 224, 3)]        0         []
#
#  input_12 (InputLayer)       [(None, 224, 224, 3)]        0         []
#
#  vgg16 (Functional)          (None, 7, 7, 512)            1471468   ['input_11[0][0]',
#                                                           8          'input_12[0][0]']
#
#  flatten_6 (Flatten)         (None, 25088)                0         ['vgg16[0][0]']
#
#  flatten_7 (Flatten)         (None, 25088)                0         ['vgg16[1][0]']
#
#  concatenate_3 (Concatenate  (None, 50176)                0         ['flatten_6[0][0]',
#  )                                                                   'flatten_7[0][0]']
#
#  dense_9 (Dense)             (None, 512)                  2569062   ['concatenate_3[0][0]']
#                                                           4
#
#  dropout_6 (Dropout)         (None, 512)                  0         ['dense_9[0][0]']
#
#  dense_10 (Dense)            (None, 256)                  131328    ['dropout_6[0][0]']
#
#  dropout_7 (Dropout)         (None, 256)                  0         ['dense_10[0][0]']
#
#  dense_11 (Dense)            (None, 1)                    257       ['dropout_7[0][0]']
#
# ==================================================================================================
# Total params: 40536897 (154.64 MB)
# Trainable params: 32901633 (125.51 MB)
# Non-trainable params: 7635264 (29.13 MB)
# __________________________________________________________________________________________________
# Epoch 1/50
# 24/24 [==============================] - 14s 478ms/step - loss: 12.9773 - accuracy: 0.5421 - val_loss: 11.0916 - val_accuracy: 0.3632
# Epoch 2/50
# 24/24 [==============================] - 10s 437ms/step - loss: 9.8983 - accuracy: 0.6053 - val_loss: 8.7948 - val_accuracy: 0.3474
# Epoch 3/50
# 24/24 [==============================] - 11s 446ms/step - loss: 7.9752 - accuracy: 0.6868 - val_loss: 7.2583 - val_accuracy: 0.6000
# Epoch 4/50
# 24/24 [==============================] - 10s 404ms/step - loss: 6.6815 - accuracy: 0.7579 - val_loss: 6.2372 - val_accuracy: 0.6158
# Epoch 5/50
# 24/24 [==============================] - 10s 435ms/step - loss: 5.7802 - accuracy: 0.8342 - val_loss: 5.4911 - val_accuracy: 0.6263
# Epoch 6/50
# 24/24 [==============================] - 10s 431ms/step - loss: 5.0971 - accuracy: 0.8829 - val_loss: 4.9088 - val_accuracy: 0.6474
# Epoch 7/50
# 24/24 [==============================] - 9s 383ms/step - loss: 4.5465 - accuracy: 0.9171 - val_loss: 4.4480 - val_accuracy: 0.6474
# Epoch 8/50
# 24/24 [==============================] - 10s 424ms/step - loss: 4.0930 - accuracy: 0.9421 - val_loss: 4.0496 - val_accuracy: 0.6684
# Epoch 9/50
# 24/24 [==============================] - 10s 427ms/step - loss: 3.7032 - accuracy: 0.9447 - val_loss: 3.7191 - val_accuracy: 0.6474
# Epoch 10/50
# 24/24 [==============================] - 10s 432ms/step - loss: 3.3743 - accuracy: 0.9447 - val_loss: 3.4565 - val_accuracy: 0.6316
# Epoch 11/50
# 24/24 [==============================] - 9s 396ms/step - loss: 3.0814 - accuracy: 0.9553 - val_loss: 3.1686 - val_accuracy: 0.6579
# Epoch 12/50
# 24/24 [==============================] - 9s 394ms/step - loss: 2.8190 - accuracy: 0.9513 - val_loss: 2.9683 - val_accuracy: 0.6211
# Epoch 13/50
# 24/24 [==============================] - 10s 435ms/step - loss: 2.5936 - accuracy: 0.9605 - val_loss: 2.7264 - val_accuracy: 0.6947
# Epoch 14/50
# 24/24 [==============================] - 10s 435ms/step - loss: 2.3927 - accuracy: 0.9579 - val_loss: 2.5815 - val_accuracy: 0.6263
# Epoch 15/50
# Epoch 35/50
# 24/24 [==============================] - 10s 433ms/step - loss: 0.5799 - accuracy: 0.9908 - val_loss: 1.0538 - val_accuracy: 0.6368
# Epoch 36/50
# 24/24 [==============================] - 9s 387ms/step - loss: 0.5467 - accuracy: 0.9908 - val_loss: 1.0358 - val_accuracy: 0.6474
# Epoch 37/50
# 24/24 [==============================] - 10s 436ms/step - loss: 0.5247 - accuracy: 0.9776 - val_loss: 1.0199 - val_accuracy: 0.6211
# Epoch 38/50
# 24/24 [==============================] - 10s 433ms/step - loss: 0.5020 - accuracy: 0.9842 - val_loss: 1.0161 - val_accuracy: 0.5947
# Epoch 39/50
# 24/24 [==============================] - 10s 431ms/step - loss: 0.4756 - accuracy: 0.9895 - val_loss: 0.9644 - val_accuracy: 0.6158
# Epoch 40/50
# 24/24 [==============================] - 9s 388ms/step - loss: 0.4460 - accuracy: 0.9947 - val_loss: 0.9484 - val_accuracy: 0.6526
# Epoch 41/50
# 24/24 [==============================] - 10s 435ms/step - loss: 0.4324 - accuracy: 0.9882 - val_loss: 0.9156 - val_accuracy: 0.6526
# Epoch 42/50
# 24/24 [==============================] - 10s 436ms/step - loss: 0.4187 - accuracy: 0.9882 - val_loss: 0.9003 - val_accuracy: 0.6368
# Epoch 43/50
# 24/24 [==============================] - 9s 381ms/step - loss: 0.3949 - accuracy: 0.9921 - val_loss: 0.9295 - val_accuracy: 0.6368
# Epoch 44/50
# 24/24 [==============================] - 10s 430ms/step - loss: 0.3774 - accuracy: 0.9868 - val_loss: 0.9003 - val_accuracy: 0.6263
# Epoch 45/50
# 24/24 [==============================] - 9s 386ms/step - loss: 0.3686 - accuracy: 0.9895 - val_loss: 0.8570 - val_accuracy: 0.6474
# Epoch 46/50
# 24/24 [==============================] - 10s 425ms/step - loss: 0.3525 - accuracy: 0.9947 - val_loss: 0.8671 - val_accuracy: 0.6158
# Epoch 47/50
# 24/24 [==============================] - 10s 431ms/step - loss: 0.3363 - accuracy: 0.9921 - val_loss: 0.8557 - val_accuracy: 0.6526
# Epoch 48/50
# 24/24 [==============================] - 9s 387ms/step - loss: 0.3289 - accuracy: 0.9947 - val_loss: 0.8489 - val_accuracy: 0.6000
# Epoch 49/50
# 24/24 [==============================] - 10s 426ms/step - loss: 0.3153 - accuracy: 0.9947 - val_loss: 0.8663 - val_accuracy: 0.6158
# Epoch 50/50
# 24/24 [==============================] - 10s 433ms/step - loss: 0.3047 - accuracy: 0.9908 - val_loss: 0.8474 - val_accuracy: 0.6368
# 6/6 [==============================] - 2s 248ms/step - loss: 0.7926 - accuracy: 0.6444
# Test accuracy: 0.64

# %%
# Prepare the data for the plot_out function
loss_hist = {
    "train": history.history['loss'],
    "val": history.history['val_loss']
}

metric_hist = {
    "train": history.history['accuracy'],
    "val": history.history['val_accuracy']
}

# Call the plot_out function
plot_out(loss_hist, metric_hist, epochs=len(history.history['loss']))

# %% [markdown]
# ## Unfreezing more layers (last 6)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, regularizers, callbacks

input_shape = (224, 224, 3)
learning_rate = 1e-4

def create_model(input_shape):
    base_model = tf.keras.applications.VGG16(include_top=False, input_shape=input_shape, weights='imagenet')

    for layer in base_model.layers:
        layer.trainable = False

    for layer in base_model.layers[-6:]:
        layer.trainable = True

    input_1 = layers.Input(shape=input_shape)
    input_2 = layers.Input(shape=input_shape)

    x1 = base_model(input_1)
    x2 = base_model(input_2)

    x1 = layers.Flatten()(x1)
    x2 = layers.Flatten()(x2)

    concatenated = layers.Concatenate()([x1, x2])

    dense = layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.01), activity_regularizer=regularizers.l2(0.01))(concatenated)
    dense = layers.Dropout(0.6)(dense)  # Increased dropout rate
    dense = layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01), activity_regularizer=regularizers.l2(0.01))(dense)
    dense = layers.Dropout(0.6)(dense)  # Increased dropout rate
    output = layers.Dense(1, activation='sigmoid')(dense)

    model = models.Model(inputs=[input_1, input_2], outputs=output)

    optimizer = optimizers.Adam(learning_rate=learning_rate)

    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    return model

model = create_model(input_shape)
model.summary()

early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit([train_pairs[:, 0], train_pairs[:, 1]], train_labels,
                    epochs=50, batch_size=32, validation_split=0.2,
                    callbacks=[early_stopping])

test_loss, test_accuracy = model.evaluate([test_pairs[:, 0], test_pairs[:, 1]], test_labels)
print(f'Test accuracy: {test_accuracy:.2f}')
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_17 (InputLayer)       [(None, 224, 224, 3)]        0         []
#
#  input_18 (InputLayer)       [(None, 224, 224, 3)]        0         []
#
#  vgg16 (Functional)          (None, 7, 7, 512)            1471468   ['input_17[0][0]',
#                                                           8          'input_18[0][0]']
#
#  flatten_6 (Flatten)         (None, 25088)                0         ['vgg16[0][0]']
#
#  flatten_7 (Flatten)         (None, 25088)                0         ['vgg16[1][0]']
#
#  concatenate_5 (Concatenate  (None, 50176)                0         ['flatten_6[0][0]',
#  )                                                                   'flatten_7[0][0]']
#
#  dense_15 (Dense)            (None, 512)                  2569062   ['concatenate_5[0][0]']
#                                                           4
#
#  dropout_8 (Dropout)         (None, 512)                  0         ['dense_15[0][0]']
#
#  dense_16 (Dense)            (None,
# 24/24 [==============================] - 10s 424ms/step - loss: 0.4314 - accuracy: 0.9895 - val_loss: 0.9214 - val_accuracy: 0.7211
# Epoch 40/50
# 24/24 [==============================] - 10s 419ms/step - loss: 0.4188 - accuracy: 0.9868 - val_loss: 1.0638 - val_accuracy: 0.6579
# Epoch 41/50
# 24/24 [==============================] - 11s 454ms/step - loss: 0.3930 - accuracy: 0.9921 - val_loss: 0.9059 - val_accuracy: 0.6947
# Epoch 42/50
# 24/24 [==============================] - 10s 413ms/step - loss: 0.3800 - accuracy: 0.9934 - val_loss: 0.8506 - val_accuracy: 0.7053
# Epoch 43/50
# 24/24 [==============================] - 11s 452ms/step - loss: 0.3688 - accuracy: 0.9895 - val_loss: 0.8042 - val_accuracy: 0.7316
# Epoch 44/50
# 24/24 [==============================] - 11s 447ms/step - loss: 0.3513 - accuracy: 0.9921 - val_loss: 0.8201 - val_accuracy: 0.7000
# Epoch 45/50
# 24/24 [==============================] - 11s 444ms/step - loss: 0.3337 - accuracy: 0.9934 - val_loss: 0.8132 - val_accuracy: 0.7105
# Epoch 46/50
# 24/24 [==============================] - 11s 445ms/step - loss: 0.3231 - accuracy: 0.9947 - val_loss: 0.8077 - val_accuracy: 0.7000
# Epoch 47/50
# 24/24 [==============================] - 11s 452ms/step - loss: 0.3079 - accuracy: 0.9947 - val_loss: 0.7824 - val_accuracy: 0.7158
# Epoch 48/50
# 24/24 [==============================] - 11s 449ms/step - loss: 0.2972 - accuracy: 0.9961 - val_loss: 0.8496 - val_accuracy: 0.7105
# Epoch 49/50
# 24/24 [==============================] - 10s 401ms/step - loss: 0.2878 - accuracy: 0.9947 - val_loss: 0.8042 - val_accuracy: 0.7105
# Epoch 50/50
# 24/24 [==============================] - 11s 444ms/step - loss: 0.2826 - accuracy: 0.9934 - val_loss: 0.7940 - val_accuracy: 0.7263
# 6/6 [==============================] - 1s 235ms/step - loss: 0.9458 - accuracy: 0.6000
# Test accuracy: 0.60

# %%
# Prepare the data for the plot_out function
loss_hist = {
    "train": history.history['loss'],
    "val": history.history['val_loss']
}

metric_hist = {
    "train": history.history['accuracy'],
    "val": history.history['val_accuracy']
}

# Call the plot_out function
plot_out(loss_hist, metric_hist, epochs=len(history.history['loss']))

# %% [markdown]
# # THE BEST IS: Unfreezing more layers (last 4) + regularitzation l2 + dropout

# %% [markdown]
# ### Now, let's try this but using ResNet50

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, regularizers, callbacks

input_shape = (224, 224, 3)
learning_rate = 1e-4

def create_model(input_shape):
    base_model = tf.keras.applications.ResNet50(include_top=False, input_shape=input_shape, weights='imagenet')

    for layer in base_model.layers:
        layer.trainable = False

    for layer in base_model.layers[-4:]:
        layer.trainable = True

    input_1 = layers.Input(shape=input_shape)
    input_2 = layers.Input(shape=input_shape)

    x1 = base_model(input_1)
    x2 = base_model(input_2)

    x1 = layers.GlobalAveragePooling2D()(x1)
    x2 = layers.GlobalAveragePooling2D()(x2)

    concatenated = layers.Concatenate()([x1, x2])

    dense = layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.01), activity_regularizer=regularizers.l2(0.01))(concatenated)
    dense = layers.Dropout(0.6)(dense)  # Increased dropout rate
    dense = layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01), activity_regularizer=regularizers.l2(0.01))(dense)
    dense = layers.Dropout(0.6)(dense)  # Increased dropout rate
    output = layers.Dense(1, activation='sigmoid')(dense)

    model = models.Model(inputs=[input_1, input_2], outputs=output)

    optimizer = optimizers.Adam(learning_rate=learning_rate)

    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    return model

model = create_model(input_shape)
model.summary()

early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Ensure train_pairs and train_labels are defined before using them
history = model.fit([train_pairs[:, 0], train_pairs[:, 1]], train_labels,
                    epochs=50, batch_size=32, validation_split=0.2,
                    callbacks=[early_stopping])

test_loss, test_accuracy = model.evaluate([test_pairs[:, 0], test_pairs[:, 1]], test_labels)
print(f'Test accuracy: {test_accuracy:.2f}')
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  input_6 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  resnet50 (Functional)       (None, 7, 7, 2048)           2358771   ['input_5[0][0]',
#                                                           2          'input_6[0][0]']
#
#  global_average_pooling2d (  (None, 2048)                 0         ['resnet50[0][0]']
#  GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 2048)                 0         ['resnet50[1][0]']
#   (GlobalAveragePooling2D)
#
#  concatenate_1 (Concatenate  (None, 4096)                 0         ['global_average_pooling2d[0][
#  )                                                                  0]',
#                                                                      'global_average_pooling2d_1[0
#                                                                     ][0]']
#
#  dense_3 (Dense)             (None, 512)                  2097664   ['concatenate_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 512)                  0         ['dense_3[0][0]']
#
#  dense_4 (Dense)             (None, 256)                  131328    ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 256)                  0         ['dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 1)                    257       ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 25816961 (98.48 MB)
# Trainable params: 3283969 (12.53 MB)
# Non-trainable params: 22532992 (85.96 MB)
# __________________________________________________________________________________________________
# Epoch 1/50
# 24/24 [==============================] - 33s 918ms/step - loss: 13.5397 - accuracy: 0.5184 - val_loss: 12.4761 - val_accuracy: 0.5579
# Epoch 2/50
# 24/24 [==============================] - 6s 268ms/step - loss: 11.9296 - accuracy: 0.6237 - val_loss: 11.4634 - val_accuracy: 0.5526
# Epoch 3/50
# 24/24 [==============================] - 7s 274ms/step - loss: 10.9870 - accuracy: 0.6737 - val_loss: 10.5503 - val_accuracy: 0.5737
# 24/24 [==============================] - 6s 268ms/step - loss: 2.1626 - accuracy: 0.9526 - val_loss: 2.3790 - val_accuracy: 0.6895
# Epoch 24/50
# 24/24 [==============================] - 6s 272ms/step - loss: 2.0186 - accuracy: 0.9711 - val_loss: 2.2809 - val_accuracy: 0.6895
# Epoch 25/50
# 24/24 [==============================] - 6s 268ms/step - loss: 1.8812 - accuracy: 0.9684 - val_loss: 2.1443 - val_accuracy: 0.7105
# Epoch 26/50
# 24/24 [==============================] - 6s 270ms/step - loss: 1.7666 - accuracy: 0.9803 - val_loss: 2.0685 - val_accuracy: 0.6579
# Epoch 27/50
# 24/24 [==============================] - 6s 269ms/step - loss: 1.6603 - accuracy: 0.9697 - val_loss: 2.0077 - val_accuracy: 0.6684
# Epoch 28/50
# 24/24 [==============================] - 7s 281ms/step - loss: 1.5587 - accuracy: 0.9816 - val_loss: 1.8975 - val_accuracy: 0.7000
# Epoch 29/50
# 24/24 [==============================] - 6s 269ms/step - loss: 1.4732 - accuracy: 0.9711 - val_loss: 1.8164 - val_accuracy: 0.7000
# Epoch 30/50
# 24/24 [==============================] - 6s 271ms/step - loss: 1.3790 - accuracy: 0.9829 - val_loss: 1.7563 - val_accuracy: 0.6579
# Epoch 31/50
# 24/24 [==============================] - 6s 266ms/step - loss: 1.3117 - accuracy: 0.9763 - val_loss: 1.6759 - val_accuracy: 0.6737
# Epoch 32/50
# 24/24 [==============================] - 6s 271ms/step - loss: 1.2333 - accuracy: 0.9763 - val_loss: 1.5830 - val_accuracy: 0.6895
# Epoch 33/50
# 24/24 [==============================] - 6s 269ms/step - loss: 1.1657 - accuracy: 0.9803 - val_loss: 1.5402 - val_accuracy: 0.7000
# Epoch 34/50
# 24/24 [==============================] - 6s 269ms/step - loss: 1.1133 - accuracy: 0.9750 - val_loss: 1.5079 - val_accuracy: 0.6684
# Epoch 35/50
# 24/24 [==============================] - 6s 269ms/step - loss: 1.0440 - accuracy: 0.9895 - val_loss: 1.4655 - val_accuracy: 0.6526
# Epoch 36/50
# 24/24 [==============================] - 6s 272ms/step - loss: 1.0224 - accuracy: 0.9697 - val_loss: 1.4532 - val_accuracy: 0.6684
# Epoch 37/50
# 24/24 [==============================] - 6s 269ms/step - loss: 0.9611 - accuracy: 0.9776 - val_loss: 1.4005 - val_accuracy: 0.6421
# Epoch 38/50
# 24/24 [==============================] - 6s 273ms/step - loss: 0.9261 - accuracy: 0.9737 - val_loss: 1.3809 - val_accuracy: 0.6579
# Epoch 39/50
# 24/24 [==============================] - 6s 269ms/step - loss: 0.8756 - accuracy: 0.9763 - val_loss: 1.3283 - val_accuracy: 0.6895
# Epoch 40/50
# 24/24 [==============================] - 6s 270ms/step - loss: 0.8354 - accuracy: 0.9803 - val_loss: 1.2435 - val_accuracy: 0.6737
# Epoch 41/50
# 24/24 [==============================] - 6s 266ms/step - loss: 0.8023 - accuracy: 0.9776 - val_loss: 1.2424 - val_accuracy: 0.6579
# Epoch 42/50
# 24/24 [==============================] - 6s 271ms/step - loss: 0.7692 - accuracy: 0.9763 - val_loss: 1.2017 - val_accuracy: 0.6632
# Epoch 43/50
# 24/24 [==============================] - 6s 268ms/step - loss: 0.7422 - accuracy: 0.9737 - val_loss: 1.1634 - val_accuracy: 0.6632
# Epoch 44/50
# 24/24 [==============================] - 6s 268ms/step - loss: 0.7118 - accuracy: 0.9763 - val_loss: 1.1352 - val_accuracy: 0.6789
# Epoch 45/50
# 24/24 [==============================] - 6s 271ms/step - loss: 0.6854 - accuracy: 0.9868 - val_loss: 1.1142 - val_accuracy: 0.6947
# Epoch 46/50
# 24/24 [==============================] - 6s 261ms/step - loss: 0.6677 - accuracy: 0.9737 - val_loss: 1.1320 - val_accuracy: 0.6842
# Epoch 47/50
# 24/24 [==============================] - 6s 270ms/step - loss: 0.6346 - accuracy: 0.9816 - val_loss: 1.0607 - val_accuracy: 0.6526
# Epoch 48/50
# 24/24 [==============================] - 6s 261ms/step - loss: 0.6238 - accuracy: 0.9737 - val_loss: 1.1286 - val_accuracy: 0.6737
# Epoch 49/50
# 24/24 [==============================] - 6s 266ms/step - loss: 0.5950 - accuracy: 0.9882 - val_loss: 1.0648 - val_accuracy: 0.6737
# Epoch 50/50
# 24/24 [==============================] - 6s 265ms/step - loss: 0.5761 - accuracy: 0.9789 - val_loss: 1.0580 - val_accuracy: 0.6526
# 6/6 [==============================] - 4s 812ms/step - loss: 1.2168 - accuracy: 0.5667
# Test accuracy: 0.57

# %%
# Prepare the data for the plot_out function
loss_hist = {
    "train": history.history['loss'],
    "val": history.history['val_loss']
}

metric_hist = {
    "train": history.history['accuracy'],
    "val": history.history['val_accuracy']
}

# Call the plot_out function
plot_out(loss_hist, metric_hist, epochs=len(history.history['loss']))

# %% [markdown]
# ## Let's try the las one but only unfreezing the last 2 layers

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, regularizers, callbacks

input_shape = (224, 224, 3)
learning_rate = 1e-4

def create_model(input_shape):
    base_model = tf.keras.applications.ResNet50(include_top=False, input_shape=input_shape, weights='imagenet')

    for layer in base_model.layers:
        layer.trainable = False

    for layer in base_model.layers[-2:]:
        layer.trainable = True

    input_1 = layers.Input(shape=input_shape)
    input_2 = layers.Input(shape=input_shape)

    x1 = base_model(input_1)
    x2 = base_model(input_2)

    x1 = layers.GlobalAveragePooling2D()(x1)
    x2 = layers.GlobalAveragePooling2D()(x2)

    concatenated = layers.Concatenate()([x1, x2])

    dense = layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.01), activity_regularizer=regularizers.l2(0.01))(concatenated)
    dense = layers.Dropout(0.6)(dense)  # Increased dropout rate
    dense = layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01), activity_regularizer=regularizers.l2(0.01))(dense)
    dense = layers.Dropout(0.6)(dense)  # Increased dropout rate
    output = layers.Dense(1, activation='sigmoid')(dense)

    model = models.Model(inputs=[input_1, input_2], outputs=output)

    optimizer = optimizers.Adam(learning_rate=learning_rate)

    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    return model

model = create_model(input_shape)
model.summary()

early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Ensure train_pairs and train_labels are defined before using them
history = model.fit([train_pairs[:, 0], train_pairs[:, 1]], train_labels,
                    epochs=50, batch_size=32, validation_split=0.2,
                    callbacks=[early_stopping])

test_loss, test_accuracy = model.evaluate([test_pairs[:, 0], test_pairs[:, 1]], test_labels)
print(f'Test accuracy: {test_accuracy:.2f}')
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_11 (InputLayer)       [(None, 224, 224, 3)]        0         []
#
#  input_12 (InputLayer)       [(None, 224, 224, 3)]        0         []
#
#  resnet50 (Functional)       (None, 7, 7, 2048)           2358771   ['input_11[0][0]',
#                                                           2          'input_12[0][0]']
#
#  global_average_pooling2d_4  (None, 2048)                 0         ['resnet50[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_5  (None, 2048)                 0         ['resnet50[1][0]']
#   (GlobalAveragePooling2D)
#
#  concatenate_3 (Concatenate  (None, 4096)                 0         ['global_average_pooling2d_4[0
#  )                                                                  ][0]',
#                                                                      'global_average_pooling2d_5[0
#                                                                     ][0]']
#
#  dense_9 (Dense)             (None, 512)                  2097664   ['concatenate_3[0][0]']
#
#  dropout_6 (Dropout)         (None, 512)                  0         ['dense_9[0][0]']
#
#  dense_10 (Dense)            (None, 256)                  131328    ['dropout_6[0][0]']
#
#  dropout_7 (Dropout)         (None, 256)                  0         ['dense_10[0][0]']
#
#  dense_11 (Dense)            (None, 1)                    257       ['dropout_7[0][0]']
#
# ==================================================================================================
# Total params: 25816961 (98.48 MB)
# Trainable params: 2229249 (8.50 MB)
# Non-trainable params: 23587712 (89.98 MB)
# __________________________________________________________________________________________________
# Epoch 1/50
# 24/24 [==============================] - 19s 426ms/step - loss: 14.4223 - accuracy: 0.5197 - val_loss: 12.2282 - val_accuracy: 0.4526
# Epoch 2/50
# 24/24 [==============================] - 6s 269ms/step - loss: 11.5658 - accuracy: 0.5013 - val_loss: 10.8308 - val_accuracy: 0.5684
# Epoch 3/50
# 24/24 [==============================] - 6s 268ms/step - loss: 10.2968 - accuracy: 0.5632 - val_loss: 9.7356 - val_accuracy: 0.5737
# Epoch 4/50
# 24/24 [==============================] - 6s 270ms/step - loss: 9.2582 - accuracy: 0.5868 - val_loss: 8.7795 - val_accuracy: 0.5526
# Epoch 5/50
# 24/24 [==============================] - 6s 266ms/step - loss: 8.3539 - accuracy: 0.6039 - val_loss: 7.9326 - val_accuracy: 0.6105
# Epoch 6/50
# 24/24 [==============================] - 6s 271ms/step - loss: 7.5579 - accuracy: 0.6303 - val_loss: 7.1875 - val_accuracy: 0.6684
# Epoch 7/50
# 24/24 [==============================] - 6s 264ms/step - loss: 6.8519 - accuracy: 0.6684 - val_loss: 6.5448 - val_accuracy: 0.5789
# Epoch 8/50
# 24/24 [==============================] - 6s 265ms/step - loss: 6.2442 - accuracy: 0.6461 - val_loss: 5.9713 - val_accuracy: 0.6421
# Epoch 9/50
# 24/24 [==============================] - 6s 263ms/step - loss: 5.6977 - accuracy: 0.7013 - val_loss: 5.4717 - val_accuracy: 0.6474
# Epoch 10/50
# 24/24 [==============================] - 6s 267ms/step - loss: 5.2228 - accuracy: 0.7171 - val_loss: 5.0346 - val_accuracy: 0.6526
# Epoch 11/50
# 24/24 [==============================] - 6s 264ms/step - loss: 4.8040 - accuracy: 0.7250 - val_loss: 4.6362 - val_accuracy: 0.6684
# Epoch 12/50
# 24/24 [==============================] - 6s 263ms/step - loss: 4.4352 - accuracy: 0.7303 - val_loss: 4.2993 - val_accuracy: 0.6895
# Epoch 13/50
# 24/24 [==============================] - 6s 265ms/step - loss: 4.1007 - accuracy: 0.7868 - val_loss: 4.0024 - val_accuracy: 0.6316
# Epoch 14/50
# 24/24 [==============================] - 6s 267ms/step - loss: 3.8164 - accuracy: 0.7539 - val_loss: 3.7238 - val_accuracy: 0.7158
# Epoch 15/50
# 24/24 [==============================] - 6s 263ms/step - loss: 3.5471 - accuracy: 0.7842 - val_loss: 3.4836 - val_accuracy: 0.7421
# Epoch 16/50
# 24/24 [==============================] - 6s 267ms/step - loss: 3.3151 - accuracy: 0.7947 - val_loss: 3.2664 - val_accuracy: 0.7263
# Epoch 17/50
# 24/24 [==============================] - 6s 265ms/step - loss: 3.1096 - accuracy: 0.8013 - val_loss: 3.0772 - val_accuracy: 0.7158
# Epoch 18/50
# 24/24 [==============================] - 6s 269ms/step - loss: 2.9143 - accuracy: 0.8066 - val_loss: 2.8983 - val_accuracy: 0.7421
# Epoch 19/50
# 24/24 [==============================] - 6s 261ms/step - loss: 2.7452 - accuracy: 0.8171 - val_loss: 2.7455 - val_accuracy: 0.7368
# Epoch 20/50
# 24/24 [==============================] - 6s 268ms/step - loss: 2.5911 - accuracy: 0.8342 - val_loss: 2.6018 - val_accuracy: 0.7474
# Epoch 21/50
# 24/24 [==============================] - 6s 261ms/step - loss: 2.4474 - accuracy: 0.8329 - val_loss: 2.4773 - val_accuracy: 0.7158
# Epoch 22/50
# 24/24 [==============================] - 6s 266ms/step - loss: 2.3176 - accuracy: 0.8513 - val_loss: 2.3667 - val_accuracy: 0.7211
# Epoch 23/50
# 24/24 [==============================] - 6s 266ms/step - loss: 2.1841 - accuracy: 0.8632 - val_loss: 2.2534 - val_accuracy: 0.7421
# Epoch 24/50
# 24/24 [==============================] - 6s 262ms/step - loss: 2.0759 - accuracy: 0.8697 - val_loss: 2.1573 - val_accuracy: 0.7158
# Epoch 25/50
# 24/24 [==============================] - 6s 263ms/step - loss: 1.9719 - accuracy: 0.8711 - val_loss: 2.0691 - val_accuracy: 0.7053
# Epoch 26/50
# 24/24 [==============================] - 6s 265ms/step - loss: 1.8907 - accuracy: 0.8842 - val_loss: 1.9828 - val_accuracy: 0.7053
# Epoch 27/50
# 24/24 [==============================] - 6s 266ms/step - loss: 1.8027 - accuracy: 0.8776 - val_loss: 1.9127 - val_accuracy: 0.7158
# Epoch 28/50
# 24/24 [==============================] - 6s 266ms/step - loss: 1.7127 - accuracy: 0.8908 - val_loss: 1.8385 - val_accuracy: 0.7158
# Epoch 29/50
# 24/24 [==============================] - 6s 266ms/step - loss: 1.6452 - accuracy: 0.8829 - val_loss: 1.7864 - val_accuracy: 0.6947
# Epoch 30/50
# 24/24 [==============================] - 6s 262ms/step - loss: 1.5662 - accuracy: 0.8921 - val_loss: 1.7416 - val_accuracy: 0.7000
# Epoch 31/50
# 24/24 [==============================] - 6s 266ms/step - loss: 1.5038 - accuracy: 0.9026 - val_loss: 1.6754 - val_accuracy: 0.7105
# Epoch 32/50
# 24/24 [==============================] - 6s 265ms/step - loss: 1.4421 - accuracy: 0.8961 - val_loss: 1.6108 - val_accuracy: 0.7000
# Epoch 33/50
# 24/24 [==============================] - 6s 265ms/step - loss: 1.3900 - accuracy: 0.8921 - val_loss: 1.5699 - val_accuracy: 0.7053
# Epoch 34/50
# 24/24 [==============================] - 6s 265ms/step - loss: 1.3290 - accuracy: 0.9105 - val_loss: 1.5302 - val_accuracy: 0.7000
# Epoch 35/50
# 24/24 [==============================] - 6s 265ms/step - loss: 1.2721 - accuracy: 0.9158 - val_loss: 1.4915 - val_accuracy: 0.7053
# Epoch 36/50
# 24/24 [==============================] - 6s 265ms/step - loss: 1.2257 - accuracy: 0.9197 - val_loss: 1.4434 - val_accuracy: 0.7053
# Epoch 37/50
# 24/24 [==============================] - 6s 268ms/step - loss: 1.1800 - accuracy: 0.9158 - val_loss: 1.4154 - val_accuracy: 0.6895
# Epoch 38/50
# 24/24 [==============================] - 6s 264ms/step - loss: 1.1454 - accuracy: 0.9184 - val_loss: 1.3690 - val_accuracy: 0.6895
# Epoch 39/50
# 24/24 [==============================] - 6s 269ms/step - loss: 1.1079 - accuracy: 0.9263 - val_loss: 1.3469 - val_accuracy: 0.7053
# Epoch 40/50
# 24/24 [==============================] - 6s 264ms/step - loss: 1.0554 - accuracy: 0.9342 - val_loss: 1.3357 - val_accuracy: 0.6632
# Epoch 41/50
# 24/24 [==============================] - 6s 271ms/step - loss: 1.0142 - accuracy: 0.9447 - val_loss: 1.3018 - val_accuracy: 0.6789
# Epoch 42/50
# 24/24 [==============================] - 6s 263ms/step - loss: 0.9875 - accuracy: 0.9382 - val_loss: 1.2956 - val_accuracy: 0.7000
# Epoch 43/50
# 24/24 [==============================] - 6s 269ms/step - loss: 0.9611 - accuracy: 0.9316 - val_loss: 1.2487 - val_accuracy: 0.6895
# Epoch 44/50
# 24/24 [==============================] - 6s 266ms/step - loss: 0.9295 - accuracy: 0.9303 - val_loss: 1.2355 - val_accuracy: 0.6684
# Epoch 45/50
# 24/24 [==============================] - 6s 264ms/step - loss: 0.8916 - accuracy: 0.9447 - val_loss: 1.2226 - val_accuracy: 0.6947
# Epoch 46/50
# 24/24 [==============================] - 6s 266ms/step - loss: 0.8746 - accuracy: 0.9329 - val_loss: 1.1676 - val_accuracy: 0.7000
# Epoch 47/50
# 24/24 [==============================] - 6s 267ms/step - loss: 0.8447 - accuracy: 0.9447 - val_loss: 1.1501 - val_accuracy: 0.7105
# Epoch 48/50
# 24/24 [==============================] - 6s 262ms/step - loss: 0.8265 - accuracy: 0.9303 - val_loss: 1.1604 - val_accuracy: 0.6737
# Epoch 49/50
# 24/24 [==============================] - 6s 266ms/step - loss: 0.8085 - accuracy: 0.9329 - val_loss: 1.1287 - val_accuracy: 0.6895
# Epoch 50/50
# 24/24 [==============================] - 6s 267ms/step - loss: 0.7811 - accuracy: 0.9461 - val_loss: 1.1173 - val_accuracy: 0.6684
# 6/6 [==============================] - 1s 189ms/step - loss: 1.3193 - accuracy: 0.6000
# Test accuracy: 0.60

# %%
# Prepare the data for the plot_out function
loss_hist = {
    "train": history.history['loss'],
    "val": history.history['val_loss']
}

metric_hist = {
    "train": history.history['accuracy'],
    "val": history.history['val_accuracy']
}

# Call the plot_out function
plot_out(loss_hist, metric_hist, epochs=len(history.history['loss']))

# %% [markdown]
# ## Now undefreezing only the last

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, regularizers, callbacks

input_shape = (224, 224, 3)
learning_rate = 1e-4

def create_model(input_shape):
    base_model = tf.keras.applications.ResNet50(include_top=False, input_shape=input_shape, weights='imagenet')

    for layer in base_model.layers:
        layer.trainable = False

    for layer in base_model.layers[-1:]:
        layer.trainable = True

    input_1 = layers.Input(shape=input_shape)
    input_2 = layers.Input(shape=input_shape)

    x1 = base_model(input_1)
    x2 = base_model(input_2)

    x1 = layers.GlobalAveragePooling2D()(x1)
    x2 = layers.GlobalAveragePooling2D()(x2)

    concatenated = layers.Concatenate()([x1, x2])

    dense = layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.01), activity_regularizer=regularizers.l2(0.01))(concatenated)
    dense = layers.Dropout(0.6)(dense)  # Increased dropout rate
    dense = layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01), activity_regularizer=regularizers.l2(0.01))(dense)
    dense = layers.Dropout(0.6)(dense)  # Increased dropout rate
    output = layers.Dense(1, activation='sigmoid')(dense)

    model = models.Model(inputs=[input_1, input_2], outputs=output)

    optimizer = optimizers.Adam(learning_rate=learning_rate)

    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    return model

model = create_model(input_shape)
model.summary()

early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Ensure train_pairs and train_labels are defined before using them
history = model.fit([train_pairs[:, 0], train_pairs[:, 1]], train_labels,
                    epochs=50, batch_size=32, validation_split=0.2,
                    callbacks=[early_stopping])

test_loss, test_accuracy = model.evaluate([test_pairs[:, 0], test_pairs[:, 1]], test_labels)
print(f'Test accuracy: {test_accuracy:.2f}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 5s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  input_3 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  resnet50 (Functional)       (None, 7, 7, 2048)           2358771   ['input_2[0][0]',
#                                                           2          'input_3[0][0]']
#
#  global_average_pooling2d (  (None, 2048)                 0         ['resnet50[0][0]']
#  GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 2048)                 0         ['resnet50[1][0]']
#   (GlobalAveragePooling2D)
#
#  concatenate (Concatenate)   (None, 4096)                 0         ['global_average_pooling2d[0][
#                                                                     0]',
#                                                                      'global_average_pooling2d_1[0
#                                                                     ][0]']
#
#  dense (Dense)               (None, 512)                  2097664   ['concatenate[0][0]']
#
#  dropout (Dropout)           (None, 512)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 256)                  131328    ['dropout[0][0]']
#
#  dropout_1 (Dropout)         (None, 256)                  0         ['dense_1[0][0]']
#
#  dense_2 (Dense)             (None, 1)                    257       ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 25816961 (98.48 MB)
# Trainable params: 2229249 (8.50 MB)
# Non-trainable params: 23587712 (89.98 MB)
# __________________________________________________________________________________________________
# Epoch 1/50
# 24/24 [==============================] -
# 24/24 [==============================] - 6s 273ms/step - loss: 2.3236 - accuracy: 0.8684 - val_loss: 2.5503 - val_accuracy: 0.5053
# Epoch 22/50
# 24/24 [==============================] - 8s 331ms/step - loss: 2.1874 - accuracy: 0.8697 - val_loss: 2.4451 - val_accuracy: 0.4632
# Epoch 23/50
# 24/24 [==============================] - 7s 277ms/step - loss: 2.0674 - accuracy: 0.8882 - val_loss: 2.3561 - val_accuracy: 0.5526
# Epoch 24/50
# 24/24 [==============================] - 7s 276ms/step - loss: 1.9551 - accuracy: 0.8947 - val_loss: 2.2584 - val_accuracy: 0.5684
# Epoch 25/50
# 24/24 [==============================] - 6s 272ms/step - loss: 1.8683 - accuracy: 0.8776 - val_loss: 2.1986 - val_accuracy: 0.4842
# Epoch 26/50
# 24/24 [==============================] - 7s 277ms/step - loss: 1.7558 - accuracy: 0.9000 - val_loss: 2.1205 - val_accuracy: 0.5000
# Epoch 27/50
# 24/24 [==============================] - 6s 273ms/step - loss: 1.6759 - accuracy: 0.9039 - val_loss: 2.0427 - val_accuracy: 0.4737
# Epoch 28/50
# 24/24 [==============================] - 7s 278ms/step - loss: 1.5913 - accuracy: 0.9053 - val_loss: 1.9857 - val_accuracy: 0.4895
# Epoch 29/50
# 24/24 [==============================] - 7s 275ms/step - loss: 1.5220 - accuracy: 0.9197 - val_loss: 1.9593 - val_accuracy: 0.4842
# Epoch 30/50
# 24/24 [==============================] - 8s 333ms/step - loss: 1.4513 - accuracy: 0.9329 - val_loss: 1.8845 - val_accuracy: 0.5158
# Epoch 31/50
# 24/24 [==============================] - 7s 278ms/step - loss: 1.3897 - accuracy: 0.9197 - val_loss: 1.8039 - val_accuracy: 0.5158
# Epoch 32/50
# 24/24 [==============================] - 8s 329ms/step - loss: 1.3244 - accuracy: 0.9316 - val_loss: 1.8159 - val_accuracy: 0.4789
# Epoch 33/50
# 24/24 [==============================] - 7s 276ms/step - loss: 1.2704 - accuracy: 0.9250 - val_loss: 1.7096 - val_accuracy: 0.5368
# Epoch 34/50
# 24/24 [==============================] - 8s 332ms/step - loss: 1.2229 - accuracy: 0.9355 - val_loss: 1.7584 - val_accuracy: 0.4421
# Epoch 35/50
# 24/24 [==============================] - 7s 278ms/step - loss: 1.1913 - accuracy: 0.9250 - val_loss: 1.6808 - val_accuracy: 0.5053
# Epoch 36/50
# 24/24 [==============================] - 7s 283ms/step - loss: 1.1209 - accuracy: 0.9382 - val_loss: 1.6666 - val_accuracy: 0.4895
# Epoch 37/50
# 24/24 [==============================] - 7s 281ms/step - loss: 1.0687 - accuracy: 0.9421 - val_loss: 1.5821 - val_accuracy: 0.5105
# Epoch 38/50
# 24/24 [==============================] - 7s 279ms/step - loss: 1.0375 - accuracy: 0.9474 - val_loss: 1.6201 - val_accuracy: 0.4789
# Epoch 39/50
# 24/24 [==============================] - 7s 281ms/step - loss: 1.0222 - accuracy: 0.9316 - val_loss: 1.5494 - val_accuracy: 0.4947
# Epoch 40/50
# 24/24 [==============================] - 7s 281ms/step - loss: 0.9723 - accuracy: 0.9395 - val_loss: 1.5582 - val_accuracy: 0.4842
# Epoch 41/50
# 24/24 [==============================] - 7s 282ms/step - loss: 0.9296 - accuracy: 0.9461 - val_loss: 1.5237 - val_accuracy: 0.4842
# Epoch 42/50
# 24/24 [==============================] - 8s 340ms/step - loss: 0.8966 - accuracy: 0.9513 - val_loss: 1.4796 - val_accuracy: 0.4947
# Epoch 43/50
# 24/24 [==============================] - 7s 276ms/step - loss: 0.8768 - accuracy: 0.9421 - val_loss: 1.5009 - val_accuracy: 0.4474
# Epoch 44/50
# 24/24 [==============================] - 7s 287ms/step - loss: 0.8504 - accuracy: 0.9447 - val_loss: 1.4176 - val_accuracy: 0.5421
# Epoch 45/50
# 24/24 [==============================] - 8s 331ms/step - loss: 0.8178 - accuracy: 0.9645 - val_loss: 1.4653 - val_accuracy: 0.4737
# Epoch 46/50
# 24/24 [==============================] - 8s 339ms/step - loss: 0.7813 - accuracy: 0.9632 - val_loss: 1.4037 - val_accuracy: 0.5158
# Epoch 47/50
# 24/24 [==============================] - 7s 287ms/step - loss: 0.7642 - accuracy: 0.9605 - val_loss: 1.3574 - val_accuracy: 0.5368
# Epoch 48/50
# 24/24 [==============================] - 8s 333ms/step - loss: 0.7470 - accuracy: 0.9566 - val_loss: 1.3854 - val_accuracy: 0.4947
# Epoch 49/50
# 24/24 [==============================] - 7s 282ms/step - loss: 0.7207 - accuracy: 0.9684 - val_loss: 1.3658 - val_accuracy: 0.5105
# Epoch 50/50
# 24/24 [==============================] - 7s 293ms/step - loss: 0.7151 - accuracy: 0.9566 - val_loss: 1.3808 - val_accuracy: 0.4789
# 6/6 [==============================] - 4s 840ms/step - loss: 1.2892 - accuracy: 0.5667
# Test accuracy: 0.57

# %%
# Prepare the data for the plot_out function
loss_hist = {
    "train": history.history['loss'],
    "val": history.history['val_loss']
}

metric_hist = {
    "train": history.history['accuracy'],
    "val": history.history['val_accuracy']
}

# Call the plot_out function
plot_out(loss_hist, metric_hist, epochs=len(history.history['loss']))

# %% [markdown]
# ## The best model of Vgg with early stopping of val_accuracy

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, regularizers, callbacks

input_shape = (224, 224, 3)
learning_rate = 1e-4

def create_model(input_shape):
    base_model = tf.keras.applications.VGG16(include_top=False, input_shape=input_shape, weights='imagenet')

    for layer in base_model.layers:
        layer.trainable = False

    for layer in base_model.layers[-4:]:
        layer.trainable = True

    input_1 = layers.Input(shape=input_shape)
    input_2 = layers.Input(shape=input_shape)

    x1 = base_model(input_1)
    x2 = base_model(input_2)

    x1 = layers.Flatten()(x1)
    x2 = layers.Flatten()(x2)

    concatenated = layers.Concatenate()([x1, x2])

    dense = layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01), activity_regularizer=regularizers.l2(0.01))(concatenated)
    dense = layers.Dropout(0.6)(dense)  # Increased dropout rate
    dense = layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.01), activity_regularizer=regularizers.l2(0.01))(dense)
    dense = layers.Dropout(0.6)(dense)  # Increased dropout rate
    output = layers.Dense(1, activation='sigmoid')(dense)

    model = models.Model(inputs=[input_1, input_2], outputs=output)

    optimizer = optimizers.Adam(learning_rate=learning_rate)

    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    return model

model = create_model(input_shape)
model.summary()

early_stopping = callbacks.EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True)

history = model.fit([train_pairs[:, 0], train_pairs[:, 1]], train_labels,
                    epochs=50, batch_size=32, validation_split=0.2,
                    callbacks=[early_stopping])

test_loss, test_accuracy = model.evaluate([test_pairs[:, 0], test_pairs[:, 1]], test_labels)
print(f'Test accuracy: {test_accuracy:.2f}')
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_8 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  input_9 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  vgg16 (Functional)          (None, 7, 7, 512)            1471468   ['input_8[0][0]',
#                                                           8          'input_9[0][0]']
#
#  flatten_2 (Flatten)         (None, 25088)                0         ['vgg16[0][0]']
#
#  flatten_3 (Flatten)         (None, 25088)                0         ['vgg16[1][0]']
#
#  concatenate_2 (Concatenate  (None, 50176)                0         ['flatten_2[0][0]',
#  )                                                                   'flatten_3[0][0]']
#
#  dense_6 (Dense)             (None, 256)                  1284531   ['concatenate_2[0][0]']
#                                                           2
#
#  dropout_4 (Dropout)         (None, 256)                  0         ['dense_6[0][0]']
#
#  dense_7 (Dense)             (None, 128)                  32896     ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)         (None, 128)                  0         ['dense_7[0][0]']
#
#  dense_8 (Dense)             (None, 1)                    129       ['dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 27593025 (105.26 MB)
# Trainable params: 19957761 (76.13 MB)
# Non-trainable params: 7635264 (29.13 MB)
# __________________________________________________________________________________________________
# Epoch 1/50
# 24/24 [==============================] - 14s 443ms/step - loss: 6.9125 - accuracy: 0.5145 - val_loss: 6.0132 - val_accuracy: 0.5211
# Epoch 2/50
# 24/24 [==============================] - 10s 409ms/step - loss: 5.4337 - accuracy: 0.6474 - val_loss: 4.8949 - val_accuracy: 0.6158
# Epoch 3/50
# 24/24 [==============================] - 11s 451ms/step - loss: 4.4912 - accuracy: 0.6921 - val_loss: 4.1540 - val_accuracy: 0.6316
# Epoch 4/50
# 24/24 [==============================] - 9s 398ms/step - loss: 3.8525 - accuracy: 0.7737 - val_loss: 3.6476 - val_accuracy: 0.6158
# Epoch 5/50
# 24/24 [==============================] - 11s 442ms/step - loss: 3.3927 - accuracy: 0.8316 - val_loss: 3.2775 - val_accuracy: 0.6579
# Epoch 6/50
# 24/24 [==============================] - 9s 399ms/step - loss: 3.0454 - accuracy: 0.8789 - val_loss: 3.0042 - val_accuracy: 0.6211
# Epoch 7/50
# 24/24 [==============================] - 11s 445ms/step - loss: 2.7654 - accuracy: 0.8908 - val_loss: 2.7620 - val_accuracy: 0.6684
# Epoch 8/50
# 24/24 [==============================] - 11s 447ms/step - loss: 2.5342 - accuracy: 0.9053 - val_loss: 2.5694 - val_accuracy: 0.6579
# Epoch 9/50
# 24/24 [==============================] - 11s 448ms/step - loss: 2.3420 - accuracy: 0.9276 - val_loss: 2.4001 - val_accuracy: 0.6684
# Epoch 10/50
# 24/24 [==============================] - 11s 454ms/step - loss: 2.1747 - accuracy: 0.9224 - val_loss: 2.2782 - val_accuracy: 0.6105
# Epoch 11/50
# 24/24 [==============================] - 10s 418ms/step - loss: 2.0203 - accuracy: 0.9329 - val_loss: 2.1420 - val_accuracy: 0.6474
# Epoch 12/50
# 24/24 [==============================] - 11s 453ms/step - loss: 1.8959 - accuracy: 0.9355 - val_loss: 2.0501 - val_accuracy: 0.6263
# Epoch 13/50
# 24/24 [==============================] - 10s 416ms/step - loss: 1.7648 - accuracy: 0.9526 - val_loss: 1.9476 - val_accuracy: 0.6474
# Epoch 14/50
# 24/24 [==============================] - 11s 454ms/step - loss: 1.6529 - accuracy: 0.9421 - val_loss: 1.8490 - val_accuracy: 0.6211
# Epoch 15/50
# 24/24 [==============================] - 11s 459ms/step - loss: 1.5616 - accuracy: 0.9566 - val_loss: 1.7659 - val_accuracy: 0.6526
# Epoch 16/50
# 24/24 [==============================] - 11s 461ms/step - loss: 1.4790 - accuracy: 0.9579 - val_loss: 1.7207 - val_accuracy: 0.6158
# Epoch 17/50
# 24/24 [==============================] - 11s 469ms/step - loss: 1.3887 - accuracy: 0.9605 - val_loss: 1.6291 - val_accuracy: 0.6000
# 6/6 [==============================] - 2s 267ms/step - loss: 2.7535 - accuracy: 0.6611
# Test accuracy: 0.66

# %%
# Prepare the data for the plot_out function
loss_hist = {
    "train": history.history['loss'],
    "val": history.history['val_loss']
}

metric_hist = {
    "train": history.history['accuracy'],
    "val": history.history['val_accuracy']
}

# Call the plot_out function
plot_out(loss_hist, metric_hist, epochs=len(history.history['loss']))
